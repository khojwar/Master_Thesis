# %% [markdown]
# <a href="https://colab.research.google.com/github/khojwar/Master_Thesis/blob/main/10_(Breakthrough_second_success_another_experiment)_pos_tagging_using_lstm_without_loosing_sentence_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import xml.etree.ElementTree as ET
# import numpy as np
# from sklearn.model_selection import train_test_split
# from keras.preprocessing.sequence import pad_sequences
# from keras.models import Sequential
# from keras.layers import Embedding, LSTM, Dense, TimeDistributed

# # Step 1: Data Preprocessing
# def parse_xml(xml_path):
#     tree = ET.parse(xml_path)
#     root = tree.getroot()
#     sentences = []
#     pos_tags = []
#     for sentence in root.findall('.//s'):
#         words = []
#         tags = []
#         for word_elem in sentence.findall('./w'):
#             words.append(word_elem.text)
#             tags.append(word_elem.get('ctag'))
#         sentences.append(words)
#         pos_tags.append(tags)
#     return sentences, pos_tags

# # Step 2: Word Embedding with word2vec
# def train_word2vec(sentences, embedding_dim=100):
#     # Train word2vec model here
#     # Replace this with actual word2vec training code
#     pass

# # Step 4: Sentence Sentiment Preservation
# def train_sentiment_analysis(sentences, sentiments):
#     # Train sentiment analysis model here
#     # Replace this with actual sentiment analysis training code
#     pass

# # Step 5: LSTM Architecture for POS Tagging
# def build_lstm_pos_tagging_model(vocab_size, embedding_dim, num_tags):
#     model = Sequential()
#     model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=None))
#     model.add(LSTM(units=128, return_sequences=True))
#     model.add(TimeDistributed(Dense(num_tags, activation='softmax')))
#     return model

# def main():
#     xml_path = 'your_xml_file.xml'
#     sentences, pos_tags = parse_xml(xml_path)

#     # Step 2: Word Embedding with word2vec
#     embedding_model = train_word2vec(sentences)

#     # Step 4: Sentence Sentiment Preservation
#     sentiment_labels = []  # Sentiment labels for each sentence
#     sentiment_model = train_sentiment_analysis(sentences, sentiment_labels)

#     # Create vocabulary and POS tag mapping
#     vocab = set([word for sentence in sentences for word in sentence])
#     pos_tags_set = set([tag for tags in pos_tags for tag in tags])
#     word_to_idx = {word: idx + 1 for idx, word in enumerate(vocab)}
#     tag_to_idx = {tag: idx for idx, tag in enumerate(pos_tags_set)}
#     idx_to_tag = {idx: tag for tag, idx in tag_to_idx.items()}

#     # Convert words and tags to indices
#     sentences_indices = [[word_to_idx[word] for word in sentence] for sentence in sentences]
#     pos_tags_indices = [[tag_to_idx[tag] for tag in tags] for tags in pos_tags]

#     # Split data into training and validation sets
#     sentences_train, sentences_val, pos_tags_train, pos_tags_val = train_test_split(
#         sentences_indices, pos_tags_indices, test_size=0.2, random_state=42
#     )

#     # Step 5: LSTM Architecture for POS Tagging
#     num_tags = len(tag_to_idx)
#     model = build_lstm_pos_tagging_model(len(word_to_idx) + 1, embedding_dim=100, num_tags=num_tags)
#     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#     # Train the model
#     model.fit(np.array(sentences_train), np.array(pos_tags_train), batch_size=32, epochs=10, validation_data=(sentences_val, pos_tags_val))

# if __name__ == '__main__':
#     main()

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.14)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
import xml.etree.ElementTree as ET
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences  # Update this line
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, TimeDistributed, Dropout  # Update this line

# %% [markdown]
# # Function for Step 1: Data Preprocessing

# %%
# # Function for Step 1: Data Preprocessing
# def parse_xml(xml_path):
#     tree = ET.parse(xml_path)
#     root = tree.getroot()
#     sentences = []
#     pos_tags = []
#     for sentence in root.findall('.//s'):
#         words = []
#         tags = []
#         for word_elem in sentence.findall('./w'):
#             words.append(word_elem.text)
#             tags.append(word_elem.get('ctag'))
#         sentences.append(words)
#         pos_tags.append(tags)
#     return sentences, pos_tags

# %%
# file_path = "book-academic-jana-siksha-2058.xml"
# sentences, pos_tags = parse_xml(file_path)

# %% [markdown]
# # function for Step 2: Word Embedding with word2vec

# %%
# !pip install --upgrade gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.3.0)

# %%
# from gensim.models import Word2Vec

# # Step 2: Word Embedding with word2vec
# def train_word2vec(sentences, embedding_dim=100):
#     # Train word2vec model here
#     model = Word2Vec(sentences, vector_size=embedding_dim, window=5, min_count=1, workers=4)
#     return model

# %%
# file_path = "book-academic-jana-siksha-2058.xml"
# sentences, pos_tags = parse_xml(file_path)

# # Step 2: Word Embedding with word2vec
# embedding_dim = 100  # Change this to your desired embedding dimension
# embedding_model = train_word2vec(sentences, embedding_dim)

# %% [markdown]
# # Function for Step 4: Sentence Sentiment Preservation

# %%
# from tensorflow.keras.preprocessing.text import Tokenizer


# # Step 4: Sentence Sentiment Preservation
# def train_sentiment_analysis(sentences, sentiments):
#     # Train sentiment analysis model here
#     tokenizer = Tokenizer()
#     tokenizer.fit_on_texts(sentences)
#     sequences = tokenizer.texts_to_sequences(sentences)
#     max_sequence_length = max([len(seq) for seq in sequences])
#     padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

#     sentiment_model = Sequential()
#     sentiment_model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=max_sequence_length))
#     sentiment_model.add(LSTM(units=128))
#     sentiment_model.add(Dense(1, activation='sigmoid'))
#     sentiment_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#     X_train, X_val, y_train, y_val = train_test_split(padded_sequences, sentiments, test_size=0.2, random_state=42)

#     sentiment_model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=10)

#     return sentiment_model

# %% [markdown]
# # function for Step 5: LSTM Architecture for POS Tagging

# %%
# # Step 5: LSTM Architecture for POS Tagging
# def build_lstm_pos_tagging_model(vocab_size, embedding_dim, num_tags):
#     model = Sequential()
#     model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=None))
#     model.add(LSTM(units=128, return_sequences=True))
#     model.add(TimeDistributed(Dense(num_tags, activation='softmax')))
#     return model

# %% [markdown]
# # Lets Start from begining

# %% [markdown]
# # step 1:

# %%
def parse_xml(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    sentences = []
    pos_tags = []
    for sentence in root.findall('.//s'):
        words = []
        tags = []
        for word_elem in sentence.findall('./w'):
            words.append(word_elem.text)
            tags.append(word_elem.get('ctag'))
        sentences.append(words)
        pos_tags.append(tags)
    return sentences, pos_tags, sentences, pos_tags, words, tags

# %%
file_path = "book-academic-jana-siksha-2058.xml"
sentences, pos_tags, words, tags = parse_xml(file_path)

# %%
print(tags)
print(words)
print(pos_tags)
print(sentences)
# Out:
# ['NN', 'VOYN1', 'YF']
# ['जत्क', 'हेर्नुहोस्', '।']
# [['JX', 'NN', 'NN', 'NN', 'YM', 'NN', 'NN', 'IKM', 'JX', 'NN', 'NN', 'NN', 'MM', 'NN', 'II', 'JX', 'NN', 'CC', 'NN', 'IKO', 'II', 'NN', 'MM'], ['MM', 'NN'], ['FB', 'NN', 'CC', 'NN', 'NN', 'MM', 'YM', 'NN', 'MM', 'MM', 'NN'], ['JX', 'NN', 'NN', 'NN', 'YM', 'NN', 'NN', 'IKM', 'JX', 'NN'], ['YB', 'DDX', 'II', 'JX', 'NN', 'NN', 'IKM', 'JX', 'NN', 'YB'], ['NN', 'NN', 'NN', 'FO', 'NN', 'FO', 'YM', 'NN', 'NN', 'YM', 'NN', 'VVYN1', 'YM', 'VI', 'JX'], ['NN', 'NN', 'NN', 'NN', 'YM', 'NN', 'NN', 'JX', 'NN', 'YB', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'YF'], ['FO', 'NN', 'NN', 'YB', 'NN', 'NN', 'FO'], ['DDX', 'NN', 'NN', 'II', 'RR', 'NN', 'JX', 'VVYN1', 'YF'], ['DDX', 'NN', 'NN', 'NN', 'II', 'JX', 'NN', 'II', 'JX', 'CC', 'NN', 'NN', 'NP', 'IKM', 'NN', 'II', 'NN', 'VE', 'IKM', 'VVYN1', 'YF'], ['NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'YM', 'NN', 'NN', 'NN', 'YM', 'FB', 'NP', 'NP', 'YF'], ['NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'YM', 'FZ', 'NN', 'YF'], ['DDX', 'II', 'JX', 'NN', 'IKO', 'JX', 'NN', 'IH', 'II', 'NN', 'IH', 'CC', 'NN', 'NN', 'CC', 'NN', 'NN', 'NP', 'IKM', 'RR', 'NN', 'VVYN1', 'CSA', 'DKX', 'JX', 'VVYN1', 'YF'], ['JX', 'NN', 'IH', 'RR', 'IKM', 'JX', 'NN', 'II', 'VE', 'IKO', 'VVYX2', 'YF'], ['NN', 'II', 'NN', 'YM', 'NN', 'YM', 'NN', 'NN', 'VVYN1', 'YF'], ['CC', 'JX', 'JX', 'NN', 'JX', 'VVYX2', 'CSA', 'VVYN1', 'YF'], ['DDX', 'NN', 'II', 'VI', 'IKM', 'NN', 'JX', 'NN', 'IKM', 'NN', 'VVYN1', 'YF'], ['JX', 'NN', 'MLF', 'IKO', 'NP'], ['NN', 'NN', 'NP', 'NN', 'CC', 'NN', 'NP', 'NN'], ['JX', 'NN', 'NN', 'NN'], ['NN', 'CC', 'NN', 'NN', 'NN', 'NP', 'NN'], ['DDX', 'II', 'JX', 'JX', 'NN', 'IH', 'JX', 'NN', 'VVYX2', 'YF'], ['DDX', 'II', 'JX', 'NN', 'IH', 'DDX', 'NN', 'IKM', 'NN', 'NN', 'CC', 'NN', 'DJX', 'IE', 'TT', 'NN', 'NN', 'TT', 'NN', 'VI', 'VVYN1', 'YF'], ['JX', 'CC', 'JX', 'NN', 'II', 'NN', 'VDO', 'NN', 'VQ', 'NN', 'VN', 'NN', 'IKM', 'JX', 'NN', 'VVYN1', 'YF'], ['NN', 'NN', 'NN', 'VN', 'NN', 'RD', 'VI', 'VVYN1', 'YF'], ['NN', 'NN', 'MM', 'MM', 'MM', 'TT', 'NN', 'NP', 'NP', 'IKO', 'II', 'NN', 'VE', 'IKO', 'MM', 'MM', 'NN', 'II', 'II', 'MM', 'NN', 'NN', 'NN', 'II', 'NN', 'II', 'VDX', 'NN', 'CC', 'NN', 'MLF', 'IKO', 'NP'], ['JX', 'NN', 'NN', 'NN', 'YM', 'NN', 'NN', 'IKM', 'JX', 'NN', 'NN', 'NN', 'MM', 'NN', 'II', 'JX', 'NN', 'CC', 'NN', 'IKO', 'II', 'NN', 'MM'], ['MM', 'NN'], ['JX', 'NN', 'IKM', 'NN', 'YM', 'JX', 'IKO', 'II', 'NN', 'CC', 'NN'], ['JX', 'NN'], ['NN', 'YM', 'NN', 'YM', 'NN', 'CC', 'NN'], ['JX', 'IKO', 'II', 'NN', 'JX', 'NN', 'IH'], ['JX', 'IKO', 'II', 'NN', 'JX', 'VN', 'NN', 'II', 'NN'], ['YQ', 'JX', 'IKO', 'II', 'NN', 'YQ', 'FB', 'NN', 'IKM', 'NN'], ['JX', 'IKO', 'II', 'NN', 'JX', 'VVYN1', 'MLX', 'NN', 'II', 'NN', 'IKM', 'NN'], ['NN', 'II', 'NN', 'YM', 'NN', 'CC', 'JX', 'NN'], ['JX', 'NN', 'CC', 'NN', 'II', 'NN', 'NN', 'CC', 'NN', 'IH'], ['JX', 'IKO', 'II', 'NN', 'CC', 'JX'], ['NN', 'IKM', 'JX', 'NN', 'NN', 'II', 'NN', 'IKM', 'NN', 'NN', 'YM', 'NN', 'CC', 'NN', 'IH'], ['NN', 'NN', 'NN', 'II'], ['JX', 'NN'], ['YQ', 'JX', 'IKO', 'II', 'NN', 'NN', 'NN', 'YQ', 'IE', 'VE', 'IKO', 'NN', 'IH'], ['NN', 'NN', 'NN', 'NN', 'CC', 'NN', 'FS', 'NN', 'YM', 'NN', 'CC', 'NN'], ['JX', 'NN', 'II', 'NN'], ['JX', 'NN', 'II', 'JX', 'NN'], ['JX', 'NN', 'YB', 'NN', 'NN', 'YB'], ['JX', 'NN', 'CC', 'NN', 'IKM', 'NN'], ['RR', 'IKM', 'NN'], ['NN', 'II', 'NN', 'NN', 'YM', 'DKX', 'IE', 'NN', 'VVYN1', 'YF'], ['NN', 'IKM', 'JX', 'NN', 'NN'], ['JX', 'NN', 'IKO', 'II', 'NN', 'NN'], ['JX', 'NN', 'NN', 'NN', 'YM', 'NN', 'NN', 'NP'], ['NN'], ['NN', 'IKM', 'NN', 'YM', 'JX', 'IKO', 'II', 'NN', 'CC', 'NN'], ['JX', 'IKO', 'II', 'NN'], ['VI', 'II', 'NN', 'VI', 'VVYN1', 'FS', 'RR', 'NN', 'IKM', 'NN', 'VI', 'DDX', 'IKM', 'MOM', 'NN', 'VVYN1', 'YF'], ['DDX', 'NN', 'IA', 'VI', 'VVYN1', 'YF'], ['PRFKO', 'NN', 'VI', 'CC', 'NN', 'II', 'VI', 'VVYN1', 'YF'], ['NN', 'VI', 'VVYN1', 'YF'], ['NN', 'II', 'DDX', 'IKM', 'NN', 'TT', 'VI', 'VVYN1', 'YF'], ['MM', 'NN', 'IE', 'PMXKM', 'JX', 'NN', 'CC', 'NN', 'VE', 'IKX', 'DDX', 'NN', 'VVYN1', 'YF' ...
# [['जनमुखी', 'शिक्षा', 'सरोकार', 'मञ्च', '–', 'शिक्षा', 'समूह', 'को', 'सामयिक', 'जर्नल', 'जनशिक्षा', 'वर्ष', '७', 'शिक्षा', 'मा', 'बहुआयामिक', 'चिन्तन', 'र', 'क्रियाशीलता', 'का', 'लागि', 'अङ्क', '१५'], ['२०६२', 'वसन्त'], ['ँ', 'शिक्षा', 'र', 'समाज', 'वर्ष', '७', ',', 'अङ्क', '१५', '२०६२', 'वसन्त'], ['जनमुखी', 'शिक्षा', 'सरोकार', 'मञ्च', '–', 'शिक्षा', 'समूह', 'को', 'सामयिक', 'जर्नल'], ['(', 'यस', 'अघि', 'प्रकाशित', 'शिक्षा', 'अभियान', 'को', 'निरन्तर', 'रुप', ')'], ['क्जष्पकजब', 'चब', 'क्ब्कबव', '९भ्मगअबतष्यल', 'बलम', 'क्यअष्भतथ०', ',', 'ख्य', 'िठ', ',', 'ल्य', 'ज्ञछ', ',', 'क्उचष्लन', 'द्दण्ण्ट'], ['ँयचग्क', 'ायच', 'एयउगबचि', 'भ्मगअबतष्यल', '–', 'भ्मगअबतष्यल', 'ल्भतधयचप', 'ल्भउबुिक', 'दष्', '(', 'बललष्भ', 'िवयगचलब', 'ितय', 'उचय्कयतभ', 'जयष्कि्क', 'बलम', 'बअतष्खष्क्क', 'ष्ल', 'भमगअबतष्यल', '।'], ['९ँयच्कभचथि', 'क्जष्पकजब', 'ब्दजष्थबल', '(', 'ऋब्कउबष्नल', 'ायच', 'भ्मगअबतष्यल०'], ['यो', 'जर्नल', 'वर्ष', 'मा', 'सामान्यतया', 'दुईपटक', 'प्रकाशित', 'हुन्छ', '।'], ['यो', 'अङ्क', 'शिक्षा', 'समूह', 'द्वारा', 'स्वयंसेवी', 'रुप', 'मा', 'सम्पादित', 'र', 'एम', 'एस', 'नेपाल', 'को', 'सहयोग', 'मा', 'प्रकाशन', 'भए', 'को', 'हो', '।'], ['ख्यगिलतबचष्थि', 'भमष्तभम', 'बलम', 'उगदष्किजभम', 'दथ', 'ँयचग्क', 'ायच', 'एयउगबिच', 'भ्मगअबतष्यल', '–', 'भ्मगअबतष्यल', 'ल्भतधयचप', 'ल्भउब', ',', 'ि', 'ष्ल', 'प्बतज्कबलमग', '।'], ['एगदष्अिबतष्यल', 'बककष्कतबलअभ', 'ायच', 'तजष्क', 'ष्ककगभ', 'धबक', 'उचयखष्मभम', 'दथ', ':', 'क्', 'ल्भउब', '।'], ['यस', 'मा', 'प्रकाशित', 'लेख', 'का', 'सबै', 'विचार', 'हरु', 'मा', 'सम्पादक', 'हरु', 'वा', 'शिक्षा', 'समूह', 'वा', 'एम', 'एस', 'नेपाल', 'को', 'सधैं', 'सहमति', 'रहनुपर्छ', 'भन्ने', 'कुनै', 'जरुरी', 'छैन', '।'], ['सम्पादकीय', 'नीति', 'हरु', 'पुछार', 'को', 'भित्री', 'पाता', 'मा', 'दिइए', 'का', 'छन्', '।'], ['पाठक', 'बाट', 'प्रतिक्रिया', ',', 'लेख', ',', 'समीक्षा', 'स्वागत', 'गरिन्छ', '।'], ['तर', 'सबै', 'प्राप्त', 'सामग्री', 'प्रकाशित', 'हुन्छन्', 'भन्ने', 'छैन', '।'], ['यस', 'जर्नल', 'मा', 'नछापिनु', 'को', 'मतलब', 'प्राप्त', 'सामग्री', 'को', 'अवमूल्यन', 'होइन', '।'], ['कार्यकारी', 'सम्पादकः', 'टी', 'का', 'भट्टराई'], ['परामर्श', 'सम्पादकहरुः', 'विमल', 'फुयाल', 'र', 'डा', 'रोशन', 'चित्रकार'], ['भाषिक', 'शुध्दीकरणः', 'मेघराज', 'आचायर्'], ['व्यवस्थापन', 'र', 'सम्पादन', 'सहयोगः', 'धन', 'बहादुर', 'राइर्'], ['यस', 'मा', 'प्रकाशित', 'सबै', 'सामग्री', 'हरु', 'सार्वजनिक', 'सम्पत्ति', 'हुनेछन्', '।'], ['यस', 'मा', 'प्रकाशित', 'सामग्री', 'हरु', 'यस', 'जर्नल', 'को', 'उद्देश्य', 'प्राप्ति', 'र', 'प्रवर्द्धनकालागि', 'जस', 'ले', 'पनि', 'जनि', 'जसरि', 'पनि', 'प्रयोग', 'गर्न', 'सक्छ', '।'], ['मौखिक', 'वा', 'लिखित', 'रुप', 'मा', 'प्रयोग', 'गर्दा', 'स्रोत', 'खोलि', 'उद्धरण', 'गर्ने', 'प्रयोगकर्ता', 'को', 'नैतिक', 'दायित्व', 'हो', '।'], ['प्रतिलिपि', 'अधिकार', 'दाबी', 'गर्ने', 'समाग्री', 'यहां', 'नपठाउनु', 'होला', '।'], ['मूल्य', 'रुः', 'एक', 'सय', 'पचास', 'मात्र', 'आवरणः', 'सिरहा', 'नगरपालि', 'का', 'मा', 'लठ्ठी', 'लिए', 'का', 'एक', 'एक', 'शिक्षक', 'अगाडि', 'बाट', '२', 'किशोरी', 'विद्यार्थी', 'प्रार्थना', 'पछि', 'कक्षा', 'तर्फ', 'जांदै', 'फोटो', 'र', 'ढाचाः', 'टी', 'का', 'भट्टराई'], ['जनमुखी', 'शिक्षा', 'सरोकार', 'मञ्च', '–', 'शिक्षा', 'समूह', 'को', 'सामयिक', 'जर्नल', 'जनशिक्षा', 'वर्ष', '७', 'शिक्षा', 'मा', 'बहुआयामिक', 'चिन्तन', 'र', 'क्रियाशीलता', 'का', 'लागि', 'अङ्क', '१५'], ['२०६२', 'वसन्त'], ['सम्पादकीय', 'शिक्षा', 'को', 'अधिकार', ',', 'सबै', 'का', 'लागि', 'शिक्षा', 'र', 'भविष्य'], ['बृहत्', 'परिदृश्य'], ['शिक्षा', ',', 'अर्थ', '–', 'राजनीति', 'र', 'यथाथर्'], ['सबै', 'का', 'लागि', 'शिक्षा', 'विशेष', 'लेख', 'हरु'], ['सबै', 'का', 'लागि', 'शिक्षा', 'प्राप्त', 'गर्ने', 'दिशा', 'मा', 'चुनौती'], ["'", 'सबै', 'का', 'लागि', 'शिक्षा', "'", 'ः', 'अठोट', 'को', 'खडेरी'], ['सबै', 'का', 'लागि', 'शिक्षा', 'राष्ट्रिय', 'कार्ययो', 'जना', 'निर्माण', 'मा', 'सहभागिता', 'को', 'प्रश्न'], ['शिक्षा', 'मा', 'आदिवासी', '–', 'जनजाति', 'र', 'बहुसांस्कृतिक', 'संवेदनशीलता'], ['सामाजिक', 'परिवर्तन', 'र', 'शिक्षा', 'मा', 'लिङ्गभेदः', 'चुनौती', 'र', 'अवसर', 'हरु'], ['सबै', 'का', 'लागि', 'शिक्षा', 'र', 'दलित'], ['विद्यालय', 'को', 'शैक्षिक', 'स्तर', 'सुधार', 'मा', 'गैससं', 'को', 'सहभ ...

# %% [markdown]
# # Step 2: Word Embedding with word2vec

# %%
# created a Word2Vec model using Gensim in Python
from gensim.models import Word2Vec

def train_word2vec(sentences, embedding_dim=100):
    model = Word2Vec(sentences, vector_size=embedding_dim, window=5, min_count=1, workers=4)
    return model

# %%
# Step 2: Word Embedding with word2vec
embedding_model = train_word2vec(sentences)

# %%
# embedding_model.wv.key_to_index

# %%
# Create vocabulary and POS tag mapping
vocab = set([word for sentence in sentences for word in sentence])
pos_tags_set = set([tag for tags in pos_tags for tag in tags])
word_to_idx = {word: idx + 1 for idx, word in enumerate(vocab)}
tag_to_idx = {tag: idx for idx, tag in enumerate(pos_tags_set)}
idx_to_tag = {idx: tag for tag, idx in tag_to_idx.items()}

# %%
# Convert words and tags to indices
sentences_indices = [[word_to_idx[word] for word in sentence] for sentence in sentences]
pos_tags_indices = [[tag_to_idx[tag] for tag in tags] for tags in pos_tags]

# %%
# Pad sequences
max_sequence_length = max([len(seq) for seq in sentences_indices])
sentences_indices_padded = pad_sequences(sentences_indices, maxlen=max_sequence_length)
pos_tags_indices_padded = pad_sequences(pos_tags_indices, maxlen=max_sequence_length)

# %%
# Split data into training and validation sets
# sentences_train, sentences_val, pos_tags_train, pos_tags_val = train_test_split(sentences_indices_padded, pos_tags_indices_padded, test_size=0.2, random_state=42)

# %%
# Splitting data into 70% train, 30% temp
sentences_train, sentences_temp, pos_tags_train, pos_tags_temp = train_test_split(sentences_indices_padded, pos_tags_indices_padded, test_size=0.3, random_state=42)

# Splitting temp data into 50% val and 50% test
sentences_val, sentences_test, pos_tags_val, pos_tags_test = train_test_split(sentences_temp, pos_tags_temp, test_size=0.5, random_state=42)

# %%
print(len(sentences_train))
print(len(pos_tags_train))
print(len(sentences_val))
print(len(pos_tags_val))
print(len(sentences_test))
print(len(pos_tags_test))
# Out:
# 1924
# 1924
# 412
# 412
# 413
# 413

# %%
# Step 5: LSTM Architecture for POS Tagging
# def build_lstm_pos_tagging_model(vocab_size, embedding_dim, num_tags):
#     model = Sequential()
#     model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=None))
#     model.add(LSTM(units=128, return_sequences=True))
#     model.add(TimeDistributed(Dense(num_tags, activation='softmax')))
#     return model

# %%
# Build the LSTM model
model = Sequential()
model.add(Embedding(input_dim=len(word_to_idx) + 1, output_dim=300, input_length=max_sequence_length))    # (number of unique words, 300-dimensional vector)
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.3))  # Adding a dropout layer with 30% dropout rate
model.add(Dense(64, activation='relu'))  # Adding an additional dense layer
model.add(TimeDistributed(Dense(len(tag_to_idx), activation='softmax')))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 303, 300)          2017200
#
#  lstm_1 (LSTM)               (None, 303, 128)          219648
#
#  dropout (Dropout)           (None, 303, 128)          0
#
#  dense (Dense)               (None, 303, 64)           8256
#
#  time_distributed (TimeDistr  (None, 303, 81)          5265
#  ibuted)
#
# =================================================================
# Total params: 2,250,369
# Trainable params: 2,250,369
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# `(None, 303, 300)` represents the shape of the input and output of this embedding layer. Here, None indicates that the batch size can vary, 303 is the sequence length of each input, and 300 is the dimensionality of the embedding vector.

# %%
# Step 5: LSTM Architecture for POS Tagging
# num_tags = len(tag_to_idx)
# model = build_lstm_pos_tagging_model(len(word_to_idx) + 1, embedding_dim=100, num_tags=num_tags)
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
# history = model.fit(sentences_train, pos_tags_train, batch_size=512, epochs=3, validation_split=0.2, verbose=1)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
# Train the model
history = model.fit(sentences_train, pos_tags_train, epochs=10, batch_size=128, validation_data=(sentences_val, pos_tags_val), verbose=1)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 44s 3s/step - loss: 0.9298 - accuracy: 0.8870 - val_loss: 0.1824 - val_accuracy: 0.9597
# Epoch 2/10
# 16/16 [==============================] - 42s 3s/step - loss: 0.1571 - accuracy: 0.9624 - val_loss: 0.1507 - val_accuracy: 0.9620
# Epoch 3/10
# 16/16 [==============================] - 32s 2s/step - loss: 0.1351 - accuracy: 0.9654 - val_loss: 0.1266 - val_accuracy: 0.9654
# Epoch 4/10
# 16/16 [==============================] - 35s 2s/step - loss: 0.1100 - accuracy: 0.9685 - val_loss: 0.1064 - val_accuracy: 0.9687
# Epoch 5/10
# 16/16 [==============================] - 33s 2s/step - loss: 0.0894 - accuracy: 0.9728 - val_loss: 0.0849 - val_accuracy: 0.9780
# Epoch 6/10
# 16/16 [==============================] - 33s 2s/step - loss: 0.0651 - accuracy: 0.9816 - val_loss: 0.0594 - val_accuracy: 0.9871
# Epoch 7/10
# 16/16 [==============================] - 34s 2s/step - loss: 0.0403 - accuracy: 0.9898 - val_loss: 0.0432 - val_accuracy: 0.9919
# Epoch 8/10
# 16/16 [==============================] - 34s 2s/step - loss: 0.0252 - accuracy: 0.9939 - val_loss: 0.0373 - val_accuracy: 0.9935
# Epoch 9/10
# 16/16 [==============================] - 35s 2s/step - loss: 0.0177 - accuracy: 0.9957 - val_loss: 0.0364 - val_accuracy: 0.9944
# Epoch 10/10
# 16/16 [==============================] - 32s 2s/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 0.0344 - val_accuracy: 0.9950

# %%
# history = model.fit(sentences_train, pos_tags_train, batch_size=32, epochs=10, validation_data=(sentences_val, pos_tags_val)

# %%
import matplotlib.pyplot as plt


# Plot accuracy over time
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Time')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss over time
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Time')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# # evaluate the model
# results = model.evaluate(sentences_val, pos_tags_val, batch_size=512, verbose=2)

# for name, value in zip(model.metrics_names, results):
#   print("%s: %.3f" % (name, value))

# %%
# Evaluate the model
loss, accuracy = model.evaluate(sentences_test, pos_tags_test)
# Out:
# 13/13 [==============================] - 4s 343ms/step - loss: 0.0301 - accuracy: 0.9953

# %% [markdown]
# # Create a plot of accuracy and loss over time
# model.fit() returns a History object that contains a dictionary with everything that happened during training:

# %%
# history_dict = history.history
# history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# import matplotlib.pyplot as plt

# # Assuming you have already trained your Keras model and have the history object
# # history = model.fit(...)

# # Plot training accuracy
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.plot(history.history['accuracy'], label='Training Accuracy')
# plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
# plt.title('Training and Validation Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()

# # Plot training loss
# plt.subplot(1, 2, 2)
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict POS tags using the trained model
predicted_tags = model.predict(sentences_test)
predicted_tags = np.argmax(predicted_tags, axis=-1)

# Flatten the true and predicted tags arrays
true_tags_flat = np.ravel(pos_tags_test)
predicted_tags_flat = np.ravel(predicted_tags)

# Create a confusion matrix
confusion_mat = confusion_matrix(true_tags_flat, predicted_tags_flat)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(30, 30))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', xticklabels=idx_to_tag.values(), yticklabels=idx_to_tag.values())
plt.xlabel('Predicted POS Tags')
plt.ylabel('True POS Tags')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 13/13 [==============================] - 4s 291ms/step

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Calculate precision, recall, and F1 score
precision = precision_score(true_tags_flat, predicted_tags_flat, average='weighted')
recall = recall_score(true_tags_flat, predicted_tags_flat, average='weighted')
f1 = f1_score(true_tags_flat, predicted_tags_flat, average='weighted')

# Calculate accuracy
accuracy = accuracy_score(true_tags_flat, predicted_tags_flat)

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Accuracy: {accuracy:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Precision: 0.9952
# Recall: 0.9953
# F1 Score: 0.9950
# Accuracy: 0.9953

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Take user input sentence
new_sentence = input("Enter a sentence: ")
tokenized_new_sentence = word_tokenize(new_sentence.lower())
new_sentence_indices = [word_to_idx.get(word, 0) for word in tokenized_new_sentence]  # Use 0 if word is not in vocabulary

# Pad the input sequence to match the model's input length
padded_new_sentence_indices = pad_sequences([new_sentence_indices], maxlen=max_sequence_length, padding='post', value=0)

# Predict POS tags for the input sentence
predicted_tag_indices = model.predict(padded_new_sentence_indices)
predicted_tags = [idx_to_tag[idx] for idx in np.argmax(predicted_tag_indices, axis=-1)[0]]

# Print the POS tagged sentence
pos_tagged_sentence = list(zip(tokenized_new_sentence, predicted_tags))
for word, pos_tag in pos_tagged_sentence:
    print(f'{word}: {pos_tag}')
# Out:
# Enter a sentence: राम लेख लेख ।
# 1/1 [==============================] - 0s 49ms/step
# राम: FO
# लेख: NN
# लेख: NN
# ।: YF

# %%
# from nltk.tokenize import word_tokenize

# # Take user input sentence
# new_sentence = input("Enter a sentence: ")
# tokenized_new_sentence = word_tokenize(new_sentence.lower())
# new_sentence_indices = [word_to_idx.get(word, 0) for word in tokenized_new_sentence]  # Use 0 if word is not in vocabulary

# # Predict POS tags for the input sentence
# predicted_tag_indices = model.predict(np.array([new_sentence_indices]))
# predicted_tags = [idx_to_tag[idx] for idx in np.argmax(predicted_tag_indices, axis=-1)[0]]

# # Print the POS tagged sentence
# pos_tagged_sentence = list(zip(tokenized_new_sentence, predicted_tags))
# for word, pos_tag in pos_tagged_sentence:
#     print(f'{word}: {pos_tag}')

# %%
# from nltk.tokenize import word_tokenize

# new_sentence = "लेख लेख ।"
# tokenized_new_sentence = word_tokenize(new_sentence.lower())
# new_sentence_indices = [word_to_idx[word] for word in tokenized_new_sentence]

# predicted_tag_indices = model.predict(np.array([new_sentence_indices]))
# predicted_tags = [list(tag_to_idx.keys())[idx] for idx in np.argmax(predicted_tag_indices, axis=-1)[0]]

# print(list(zip(tokenized_new_sentence, predicted_tags)))

# %%
# input_words = input_sentence.split()

# # Convert words to indices
# input_indices = [word_to_idx.get(word, 0) for word in input_words]

# # Pad input sequence
# input_padded = np.array([input_indices])
# input_padded = pad_sequences(input_padded, maxlen=max_sequence_length)

# # Predict POS tags using the model
# predicted_tags = model.predict(input_padded)
# predicted_tags = np.argmax(predicted_tags, axis=-1)

# # Convert predicted tag indices to tag labels
# predicted_tags_labels = [idx_to_tag[idx] for idx in predicted_tags[0]]

# # Create and return POS tagged sentence
# tagged_sentence = " ".join([f"{word}/{tag}" for word, tag in zip(input_words, predicted_tags_labels)])

# %%
# # Function to process user input sentence and provide POS tagged sentence
# def tag_user_input(input_sentence, model, word_to_idx, idx_to_tag):
#     # Tokenize input sentence
#     input_words = input_sentence.split()

#     # Convert words to indices
#     input_indices = [word_to_idx.get(word, 0) for word in input_words]

#     # Pad input sequence
#     input_padded = np.array([input_indices])
#     input_padded = pad_sequences(input_padded, maxlen=max_sequence_length)

#     # Predict POS tags using the model
#     predicted_tags = model.predict(input_padded)
#     predicted_tags = np.argmax(predicted_tags, axis=-1)

#     # Convert predicted tag indices to tag labels
#     predicted_tags_labels = [idx_to_tag[idx] for idx in predicted_tags[0]]

#     # Create and return POS tagged sentence
#     tagged_sentence = " ".join([f"{word}/{tag}" for word, tag in zip(input_words, predicted_tags_labels)])
#     return tagged_sentence

# # Take user input sentence
# user_input = input("Enter a sentence: ")

# # Tag the user input sentence
# tagged_output = tag_user_input(user_input, model, word_to_idx, idx_to_tag)

# print("POS Tagged Sentence:", tagged_output)

# %%
# import nltk
# nltk.download('punkt')

# %%
# from nltk.tokenize import word_tokenize
# new_sentence = "जनमुखी"
# tokenized_new_sentence = word_tokenize(new_sentence.lower())
# new_sentence_indices = [word_to_idx[word] for word in tokenized_new_sentence]

# predicted_tag_indices = model.predict(np.array([new_sentence_indices]))
# predicted_tags = [list(tag_to_idx.keys())[idx] for idx in np.argmax(predicted_tag_indices, axis=-1)[0]]

# print(list(zip(tokenized_new_sentence, predicted_tags)))

# %%
# # user_input = input("Enter a sentence: ")
# user_input = "तराईको गर्मी होस् वा डुबान, दुवै बेला सर्पको डर सधैं रहन्छ । सावधानी अपनाउँदा अपनाउँदै सर्पदंशको चपेटमा पर्नेहरु भइहाल्छन्, झट्ट उपचार चाहिन्छ । यस्तो बेला नेपाली सेनाले पर्साको ग्रामीण भेगलाई सेवा दिनेगरी सञ्चालन गरेको सर्पदंश उपचार केन्द्रले ठूलो भर गरेको छ ।"

# # Tokenize and preprocess user input
# user_input_tokens = user_input.split()  # Basic tokenization
# user_input_indices = [word_to_idx.get(word, 0) for word in user_input_tokens]
# print("user_input_indices: \n", user_input_indices)
# user_input_padded = pad_sequences([user_input_indices], maxlen=max_sequence_length)
# print("user_input_padded: \n", user_input_padded)

# # Use POS tagging model on user input
# pos_tag_probabilities = model.predict(user_input_padded)[0]  # Get probabilities for each tag
# print("pos_tag_probabilities: \n", pos_tag_probabilities)
# pos_tag_indices = [np.argmax(probabilities) for probabilities in pos_tag_probabilities]
# print("pos_tag_indices: \n", pos_tag_indices)
# pos_tags_predicted = [idx_to_tag[idx] for idx in pos_tag_indices]

# # Combine words and predicted POS tags
# # combined_output = ' '.join([f'{word}/{tag}' for word, tag in zip(user_input_tokens, pos_tags_predicted)])

# print("POS Tags:", pos_tags_predicted)
# # print("POS Tags:", combined_output)

# %%
# # user_input = input("Enter a sentence: ")
# user_input = "राम लेख लेख्छ । "

# # Tokenize and preprocess user input
# user_input_tokens = user_input.split()  # Basic tokenization
# user_input_indices = [word_to_idx.get(word, 0) for word in user_input_tokens]
# user_input_padded = pad_sequences([user_input_indices], maxlen=max_sequence_length)

# # Use POS tagging model on user input
# pos_tag_probabilities = model.predict(user_input_padded)[0]  # Get probabilities for each tag
# pos_tag_indices = [np.argmax(probabilities) for probabilities in pos_tag_probabilities]
# pos_tags_predicted = [idx_to_tag[idx] for idx in pos_tag_indices]

# print("POS Tags for User Input:", pos_tags_predicted)

# %%
# # user_input = input("Enter a sentence: ")
# user_input = "राम लेख लेख्छ । "

# # Tokenize and preprocess user input
# user_input_tokens = user_input.split()  # Basic tokenization
# user_input_indices = [word_to_idx.get(word, 0) for word in user_input_tokens]
# user_input_padded = pad_sequences([user_input_indices], maxlen=max_sequence_length)

# # Use POS tagging model on user input
# pos_tag_probabilities = model.predict(user_input_padded)[0]  # Get probabilities for each tag
# pos_tag_indices = [np.argmax(probabilities) for probabilities in pos_tag_probabilities]
# pos_tags_predicted = [idx_to_tag[idx] for idx in pos_tag_indices]

# # Print POS tags for user input words
# for word, tag in zip(user_input_tokens, pos_tags_predicted):
#     print(f"Word: {word}, POS Tag: {tag}")

# %%
# def pos_tag_sentence(user_input, word_to_idx, idx_to_tag, model):
#     # Preprocess user input
#     input_words = user_input.split()  # Tokenize user input
#     input_indices = [word_to_idx.get(word, 0) for word in input_words]  # Convert to indices

#     # Pad input sequence
#     max_sequence_length = model.input_shape[1]
#     padded_input_indices = pad_sequences([input_indices], maxlen=max_sequence_length, padding='post')

#     # Predict POS tags
#     predictions = model.predict(padded_input_indices)

#     # Convert predictions to POS tags
#     predicted_indices = np.argmax(predictions, axis=-1)[0]
#     predicted_tags = [idx_to_tag[idx] for idx in predicted_indices]

#     return list(zip(input_words, predicted_tags))

# %%
# user_input = "राम लेख लेख्छ ।"  # Example user input
# tagged_words = pos_tag_sentence(user_input, word_to_idx, idx_to_tag, model)
# print(tagged_words)
